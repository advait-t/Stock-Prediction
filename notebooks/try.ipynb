# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/advait_t/Desktop/Jio/Stock-Prediction/data/Final/error_df1DCMSHRIRAM.NS.csv')
df['Date'] = pd.to_datetime(df['Date'])
# make first 6 rows from yyyy-dd-mm to yyyy-mm-
df['Date'] = df['Date'].dt.strftime('%Y-%m-%d')
df = df.set_index('Date', drop = False)
df['Date'] = df.index
df.head(25)

# df['Date'][0:6] = pd.to_datetime(df['Date'][0:6], format='%Y-%m-%d')
# df['Date'][0:6] = df['Date'][0:6].dt.strftime('%Y-%m-%d')
# Out:
#                   Date  Actual_Close  Predicted_Close  \
# Date
# 2022-07-04  2022-07-04    942.200012              NaN
# 2022-07-05  2022-07-05    953.849976       987.504999
# 2022-07-06  2022-07-06    976.200012       987.928820
# 2022-07-07  2022-07-07    960.400024       963.031872
# 2022-07-08  2022-07-08    953.599976       956.072702
# 2022-07-11  2022-07-11    975.450012       968.799688
# 2022-07-12  2022-07-12    964.750000       974.182903
# 2022-07-13  2022-07-13    961.700012       971.606688
# 2022-07-14  2022-07-14    961.599976       972.610939
# 2022-07-15  2022-07-15   1018.450012       969.559901
# 2022-07-18  2022-07-18    997.799988       975.286144
# 2022-07-19  2022-07-19    984.549988       991.781881
# 2022-07-20  2022-07-20    984.500000      1001.706157
# 2022-07-21  2022-07-21    972.150024       988.992886
# 2022-07-22  2022-07-22    971.500000       982.758290
# 2022-07-25  2022-07-25    967.250000       942.832051
# ...

# %%
df.head(20)
# Out:
#                   Date  Actual_Close  Predicted_Close  \
# Date
# 2022-07-04  2022-07-04    942.200012              NaN
# 2022-07-05  2022-07-05    953.849976       987.504999
# 2022-07-06  2022-07-06    976.200012       987.928820
# 2022-07-07  2022-07-07    960.400024       963.031872
# 2022-07-08  2022-07-08    953.599976       956.072702
# 2022-07-11  2022-07-11    975.450012       968.799688
# 2022-07-12  2022-07-12    964.750000       974.182903
# 2022-07-13  2022-07-13    961.700012       971.606688
# 2022-07-14  2022-07-14    961.599976       972.610939
# 2022-07-15  2022-07-15   1018.450012       969.559901
# 2022-07-18  2022-07-18    997.799988       975.286144
# 2022-07-19  2022-07-19    984.549988       991.781881
# 2022-07-20  2022-07-20    984.500000      1001.706157
# 2022-07-21  2022-07-21    972.150024       988.992886
# 2022-07-22  2022-07-22    971.500000       982.758290
# 2022-07-25  2022-07-25    967.250000       942.832051
# ...

# %%
# fetch data from yahoo finance for the company DCMSHRIRAM.NS from 4th July 2022 to today
import yfinance as yf
df = yf.download('HDFCBANK.NS', start='2022-07-04', end='2022-10-18')
df = df.reset_index()
df['Date'] = df['Date'].dt.strftime('%Y-%m-%d')
df = df.set_index('Date', drop = False)
df['Date'] = df.index
df.head(20)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Date         Open         High          Low        Close  \
# Date
# 2022-07-04  2022-07-04  1353.699951  1360.199951  1342.250000  1355.650024
# 2022-07-05  2022-07-05  1364.000000  1379.349976  1348.300049  1352.599976
# 2022-07-06  2022-07-06  1348.000000  1373.400024  1347.099976  1371.250000
# 2022-07-07  2022-07-07  1380.000000  1398.000000  1374.449951  1395.800049
# 2022-07-08  2022-07-08  1410.000000  1410.000000  1394.750000  1397.099976
# 2022-07-11  2022-07-11  1394.000000  1409.900024  1393.250000  1406.150024
# 2022-07-12  2022-07-12  1405.250000  1405.250000  1389.400024  1391.800049
# 2022-07-13  2022-07-13  1390.000000  1394.199951  1354.250000  1357.849976
# 2022-07-14  2022-07-14  1362.000000  1372.650024  1349.250000  1351.050049
# 2022-07-15  2022-07-15  1353.000000  1364.900024  1346.800049  1362.050049
# ...

# %%
# read json file from here https://raw.githubusercontent.com/advait-t/Stock-Prediction/master/models/Model_JSON/HDFCBANK.NS.json

import json
import requests
from prophet.serialize import model_to_json, model_from_json

url = 'https://raw.githubusercontent.com/advait-t/Stock-Prediction/master/models/Model_JSON/HDFCBANK.NS.json'
r = requests.get(url)
data = r.json()
saved_model = model_from_json(data)
saved_model

# %%
# define a function to save files to a github repo

import requests
import json

def save_file_to_github(file_name, file_path, message, branch='main'):
    # file_name = 'test.txt'
    # file_path = '/Users/advait_t/Desktop/Jio/Stock-Prediction/data/Final/test.txt'
    # message = 'test'
    # branch = 'main'
    url = 'https://api.github.com/repos/advait-t/Stock-Prediction/contents/' + file_name
    headers = {'Authorization': 'token 6f7f6c8f0b7e9c9b1d7b2d1b6e7f0e2d6d7e8f9g'}
    data = {'message': message, 'branch': branch}
    files = {'content': open(file_path, 'rb')}
    r = requests.put(url, headers=headers, data=data, files=files)
    print(r.json())

save_file_to_github('test.txt', '/Users/advait_t/Desktop/Jio/Stock-Prediction/data/Final/test.txt', 'test')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/42/0lky7kn128z7ldb8l3r9lwhc0000gn/T/ipykernel_56100/2519549667.py in <module>
#      16     print(r.json())
#      17
# ---> 18 save_file_to_github('test.txt', '/Users/advait_t/Desktop/Jio/Stock-Prediction/data/Final/test.txt', 'test')
#
# /var/folders/42/0lky7kn128z7ldb8l3r9lwhc0000gn/T/ipykernel_56100/2519549667.py in save_file_to_github(file_name, file_path, message, branch)
#      12     headers = {'Authorization': 'token 6f7f6c8f0b7e9c9b1d7b2d1b6e7f0e2d6d7e8f9g'}
#      13     data = {'message': message, 'branch': branch}
# ---> 14     files = {'content': open(file_path, 'rb')}
#      15     r = requests.put(url, headers=headers, data=data, files=files)
#      16     print(r.json())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/advait_t/Desktop/Jio/Stock-Prediction/data/Final/test.txt'

# %%
# download github using pip
# !pip install PyGithub

# %%
# use github library to create a function to save files to a github repo

from github import Github

def save_file_to_github(file_name, file_path, message, branch='main'):
    # file_name = 'test.txt'
    # file_path = '/Users/advait_t/Desktop/Jio/Stock-Prediction/data/Final/test.txt'
    # message = 'test'
    # branch = 'main'
    g = Github("6f7f6c8f0b7e9c9b1d7b2d1b6e7f0e2d6d7e8f9g")
    repo = g.get_repo("advait-t/Stock-Prediction")
    contents = repo.get_contents(file_name, ref=branch)
    repo.update_file(contents.path, message, open(file_path, 'rb').read(), contents.sha, branch=branch)

save_file_to_github('test.txt', '/Users/advait_t/Desktop/Jio/Stock-Prediction/data/Final/test.txt', 'test')
# Out:
# ---------------------------------------------------------------------------
# BadCredentialsException                   Traceback (most recent call last)
# /var/folders/42/0lky7kn128z7ldb8l3r9lwhc0000gn/T/ipykernel_56100/1431120728.py in <module>
#      13     repo.update_file(contents.path, message, open(file_path, 'rb').read(), contents.sha, branch=branch)
#      14
# ---> 15 save_file_to_github('test.txt', '/Users/advait_t/Desktop/Jio/Stock-Prediction/data/Final/test.txt', 'test')
#
# /var/folders/42/0lky7kn128z7ldb8l3r9lwhc0000gn/T/ipykernel_56100/1431120728.py in save_file_to_github(file_name, file_path, message, branch)
#       9     # branch = 'main'
#      10     g = Github("6f7f6c8f0b7e9c9b1d7b2d1b6e7f0e2d6d7e8f9g")
# ---> 11     repo = g.get_repo("advait-t/Stock-Prediction")
#      12     contents = repo.get_contents(file_name, ref=branch)
#      13     repo.update_file(contents.path, message, open(file_path, 'rb').read(), contents.sha, branch=branch)
#
# ...

# %%
# use PyGithub library to create a function to save files to a github repo
from github import Github

def save_file_to_github(file_name, file_path, message, branch='main'):
    # file_name = 'test.txt'
    # file_path = '/Users/advait_t/Desktop/Jio/Stock-Prediction/data/Final/test.txt'
    # message = 'test'
    # branch = 'main'
    g = Github("6f7f6c8f0b7e9c9b1d7b2d1b6e7f0e2d6d7e8f9g")
    repo = g.get_repo("advait-t/Stock-Prediction")
    contents = repo.get_contents(file_name, ref=branch)
    repo.update_file(contents.path, message, open(file_path, 'rb').read(), contents.sha, branch=branch)

# %%
from github import Github
import pandas as pd

g = Github('', '')

# get stock-prediction repo
repo = g.get_repo('advait-t/stock-prediction-main')

# make a dummy df
df = pd.DataFrame({'a': [1,2,3], 'b': [4,5,6]})

# save df to the repo
repo.create_file('test.csv', 'test', df.to_csv())

# error 
# UnknownObjectException: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#create-or-update-file-contents"}

# save file to github using github library
from github import Github
import pandas as pd

g = Github('advait-t','h2so4AST')

# get stock-prediction repo
repo = g.get_repo('advait-t/stock-prediction-main')

# make a dummy df
df = pd.DataFrame({'a': [1,2,3], 'b': [4,5,6]})

repo.create_file('/try.csv', "committing files", df.to_csv(), branch="master")
# print('/try.csv' + ' CREATED')
# Out:
# ---------------------------------------------------------------------------
# UnknownObjectException                    Traceback (most recent call last)
# /var/folders/42/0lky7kn128z7ldb8l3r9lwhc0000gn/T/ipykernel_56100/3389753172.py in <module>
#      11
#      12 # save df to the repo
# ---> 13 repo.create_file('test.csv', 'test', df.to_csv())
#      14
#      15 # error
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/github/Repository.py in create_file(self, path, message, content, branch, committer, author)
#    2135             "PUT",
#    2136             f"{self.url}/contents/{urllib.parse.quote(path)}",
# -> 2137             input=put_parameters,
#    2138         )
#    2139
#
# ~/.pyenv/versions/3.7.3/lib/python3.7/site-packages/github/Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     353         return self.__check(
#     354             *self.requestJson(
# ...

# %%
# install google colab

# %%
# upload files to google drive

# save files to google drive

access_token = ''
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/42/0lky7kn128z7ldb8l3r9lwhc0000gn/T/ipykernel_56100/913560920.py in <module>
#       1 # def read and write files from google drive
#       2
# ----> 3 from google.colab import drive
#       4 drive.mount('/content/drive')
#       5
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
from git import Repo

repo_dir = 'stock-prediction-main'
repo = Repo(repo_dir)
# file_list = [
#     'numerical_analysis/regression_analysis/simple_regression_analysis.py',
#     'numerical_analysis/regression_analysis/simple_regression_analysis.png'
# ]
commit_message = 'Add simple regression analysis'
repo.index.add(file_list)
repo.index.commit(commit_message)
origin = repo.remote('origin')
origin.push()
